# %% [markdown]
# <a href="https://colab.research.google.com/github/Bayaniblues/DS-Unit-1-Sprint-3-Linear-Algebra/blob/master/Copy_of_Copy_of_LS_DS_133_High_Dimensional_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Quantum Warmups

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# Hadamard Gate
H = 1/math.sqrt(2) * np.array([[1, 1], [1, 1]])
print(H)
# Out:
# [[0.70710678 0.70710678]
#  [0.70710678 0.70710678]]

# %%
1/math.sqrt(2)
# Out:
# 0.7071067811865475

# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
import plotly.express as px
import pandas as pd
import numpy as np

d = np.array([[2,12,6], [3,3,9], [2,4,8]])

df = pd.DataFrame(dict(
    X=d.T[0], 
    Y=d.T[1], 
    Z=d.T[2],))
df
# Out:
#    X   Y  Z
# 0  2  12  6
# 1  3   3  9
# 2  2   4  8

# %%
fig = px.line_3d(df, x='X', y="Y", z='Z')
fig.show()
# not pass
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f3cb6879-8066-447b-951d-91cdf659e8c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f3cb6879-8066-447b-951d-91cdf659e8c5")) {
#                     Plotly.newPlot(
#                         'f3cb6879-8066-447b-951d-91cdf659e8c5',
# ...

# %%
d = np.array([[2,12,6], [3,3,9], [4,4,8]])

df = pd.DataFrame(dict(
    X=d.T[0], 
    Y=d.T[1], 
    Z=d.T[2],))
df

# row represents Point, column represents coordinate
# Out:
#    X   Y  Z
# 0  2  12  6
# 1  3   3  9
# 2  4   4  8

# %%
# Pass
def plot_me(data):
  df = pd.DataFrame(dict(
      X=data.T[1], 
      Y=data.T[2], 
      Z=data.T[0],))
  fig = px.line_3d(df, x='X', y="Y", z='Z')
  return fig.show()

#Key[z = 0, x = 1, y = 2]
d = np.array([[0,4,8], [0,10,12], [0,12,14]])
plot_me(d)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e9e4e6c3-80a0-4b68-bcdc-b83397c4c981" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e9e4e6c3-80a0-4b68-bcdc-b83397c4c981")) {
#                     Plotly.newPlot(
#                         'e9e4e6c3-80a0-4b68-bcdc-b83397c4c981',
# ...

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %% [markdown]
# The vertical line test is making sure the line graph does not repeat an x value, if the x value is repeated then it is not a function.

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %% [markdown]
# 1.   Not a function     | X = 1 repeats twice
# 2.   function           | X value does not repeat
# 3.   Not a function     | X = 9 repeats twice
# 4.   Not a function     | X = 6 repeats twice
# 5.   Not a function     | X = 2 repreats three times

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %% [markdown]
# I think the Dimensionality for the example above is 3 dimensionality for M and  dimensionality for N

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %%
# TODO
def plot_this(data):
  df = pd.DataFrame(dict(
      X=data.T[1], 
      Y=data.T[2], 
      Z=data.T[0],))
  fig = px.line_3d(df, x='X', y="Y", z='Z')
  return fig.show()

data2convert = np.array([[0,2,4], [0,3,10], [0,4,12], [0,5,14], [0,6,16]])
plot_this(data2convert)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="02343919-7f23-42eb-9385-64e62200a636" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02343919-7f23-42eb-9385-64e62200a636")) {
#                     Plotly.newPlot(
#                         '02343919-7f23-42eb-9385-64e62200a636',
# ...

# %%
def convert(data):
  if len(data[0]) == 3:
      print('pass')
  # df = pd.DataFrame(dict(X=data.T[0], Y=data.T[1], Z=data.T[2],))
  else:
      np.insert(data2convert, 0,0 axis=0)
      print(data2convert)



data2convert = np.array([[2,4], [3,10], [4,12], [5,14], [6,16]])

print(len(data2convert[0]))


convert(data2convert)
# Out:
#   File "<ipython-input-69-f016a2343e02>", line 8
#     np.insert(data2convert, 0,0 axis=0)
#                                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %%
# These problems are easier to solve as Lambda functions
# Notice how this Matrix reflect the above equation 

# Solve for P
p = lambda x1, x2 : np.array([[x1 + (3*x2)], 
                              [(2*x2) - x1]])
# Test for P
print(p(1,2))
# Out:
# [[7]
#  [3]]

# %%
# Solve for q
q = lambda x1, x2, x3 : np.array([
                                  [(4*x1) + (x2) + (2*x3)],
                                  [(2*x2) - (x1) + (3*x3)],
                                  [(5*x1) - (2*x3) + x2]])

# Test for q
print(q(1,2,3))
# Out:
# [[12]
#  [12]
#  [ 1]]

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
print("test for p")
print(p(1,2))
print("test for q")
print(q(1,2,3))
# Out:
# test for p
# [[7]
#  [3]]
# test for q
# [[12]
#  [12]
#  [ 1]]

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.

# %% [markdown]
# In data science, we modify data to the point where it's input is unrecognizable from it's output. So I guess my intuition is to track this change, when vectors are scaled they are called eiganvectors, an eiganvalue is the output value.
#
# My first experience with these values/vectors was when I discovered the free paint program GIMP, in 8th grade. When scaling the images up and down I suppose the resulting width/height were the Eiganvalues.

# %%
import numpy as np
# Eigan value 
eigenvalue = lambda l : np.linalg.det(np.array([[3-l, 1], [0, 2-l]]))
eigenvalue(5)

H = 1/math.sqrt(2) * np.array([[1, 1], [1, 1]])
# Out:
# 6.0

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?

# %% [markdown]
# The "Curse of Dimensionality" mean that it is difficult to model data sets of the hundreds of thousands. I can model 3d plots with plotly, I can model 4D by expressing data as color, and at best 5D by expressing data points as shape sizes.
#
# I've been trying to solve multidimentional models for a couple months now, and I've concluded that any more visualizations in higher spacial dimensions will need to be tested in opengl.

# %% [markdown]
# ## 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?

# %% [markdown]
# I need to limit the ratio of rows to perimeters or risk overfitting the data.

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Code for loading and cleaning the 2013 national dataset from the [Housing Affordability Data System (HADS)](https://www.huduser.gov/portal/datasets/hads/hads.html) --housing data, can be found below.
#
# ## Perform PCA on the processed dataset `national_processed` (Make sure you standardize your data!) and then make a scatterplot of PC1 against PC2. Some of our discussion and work around PCA with this dataset will continue during tomorrow's lecture and assignment.
#
# Not only does this dataset have decent amount columns to begin with (99), but in preparing the data for PCA we have also [one-hot-encoded](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f#targetText=One%20hot%20encoding%20is%20a,the%20entry%20in%20the%20dataset.) all of the categorical variables. This has the effect of creating a new column for each individual category of each categorical variable. After processing this dataset has 64738 columns. --Das a lot of columns.
#
# Don't worry too much about the mechanics of one-hot encoding right now, you will learn and experiment with a whole bunch of categorical encoding approaches in unit 2.
#
# The code below will read in the dataset and perform the one-hot encoding of the categorical variables. Start adding your PCA code at the bottom of the provided code.

# %%
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read Natinal Data 
national_url = 'https://www.huduser.gov/portal/datasets/hads/hads2013n_ASCII.zip'
national_file = 'thads2013n.txt'

if os.path.exists(national_file):
    national = pd.read_csv(national_file)
else: 
    z_national = urlopen(national_url)
    zip_national = ZipFile(BytesIO(z_national.read())).extract(national_file)
    national = pd.read_csv(zip_national)

print(national.shape)
national.head()
# Out:
# (64535, 99)
#           CONTROL  AGE1 METRO3  ...          FMTBURDEN  FMTREGION  FMTSTATUS
# 0  '100003130103'    82    '3'  ...     '2 30% to 50%'       '-5'       '-5'
# 1  '100006110249'    50    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 2  '100006370140'    53    '5'  ...    '3 50% or More'       '-5'       '-5'
# 3  '100006520140'    67    '5'  ...  '1 Less than 30%'       '-5'       '-5'
# 4  '100007130148'    26    '1'  ...  '1 Less than 30%'       '-5'       '-5'
#
# [5 rows x 99 columns]

# %%
# Look at datatypes
# a lot of object datatypes even though they seem to be strings of numbers.
national.dtypes
# Out:
# CONTROL            object
# AGE1                int64
# METRO3             object
# REGION             object
# LMED                int64
#                     ...
# FMTINCRELAMICAT    object
# FMTASSISTED        object
# FMTBURDEN          object
# FMTREGION          object
# FMTSTATUS          object
# Length: 99, dtype: object

# %%
# check for null values
national.isnull().sum().any()
# Out:
# False

# %%
# check for number of categorical vs numeric columns
cat_cols = national.columns[national.dtypes=='object']
num_cols = national.columns[national.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 32 categorical columns
# 67 numerical columns

# %%
# We're making a copy of our data in case we mess something up.
national_processed = national.copy()

# Categorically Encode our Variables:
# They need to all be numeric before we do PCA.
# https://pbpython.com/categorical-encoding.html

# Cast categorical columns to "category" data type
national_processed[cat_cols] = national_processed[cat_cols].astype('category')

national_processed.dtypes
# Out:
# CONTROL            category
# AGE1                  int64
# METRO3             category
# REGION             category
# LMED                  int64
#                      ...
# FMTINCRELAMICAT    category
# FMTASSISTED        category
# FMTBURDEN          category
# FMTREGION          category
# FMTSTATUS          category
# Length: 99, dtype: object

# %%
# Replace all category cell values with their numeric category codes
for col in cat_cols:
  national_processed[col] = national_processed[col].cat.codes

print(national_processed.shape)
national_processed.head()
# Out:
# (64535, 99)
#    CONTROL  AGE1  METRO3  REGION  ...  FMTASSISTED  FMTBURDEN  FMTREGION  FMTSTATUS
# 0        0    82       2       0  ...            0          2          0          0
# 1        1    50       4       2  ...            0          1          0          0
# 2        2    53       4       2  ...            0          3          0          0
# 3        3    67       4       2  ...            0          1          0          0
# 4        4    26       0       2  ...            1          1          0          0
#
# [5 rows x 99 columns]

# %%
national_processed["CONTROL"]
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 64530    64530
# 64531    64531
# 64532    64532
# 64533    64533
# 64534    64534
# Name: CONTROL, Length: 64535, dtype: int32

# %%
# Now we only ahve numeric columns (ints and floats)
national_processed.dtypes
# Out:
# CONTROL            int32
# AGE1               int64
# METRO3              int8
# REGION              int8
# LMED               int64
#                    ...
# FMTINCRELAMICAT     int8
# FMTASSISTED         int8
# FMTBURDEN           int8
# FMTREGION           int8
# FMTSTATUS           int8
# Length: 99, dtype: object

# %% [markdown]
# ### PCA

# %%
from numpy import array
from numpy import mean
from numpy import std
from numpy import cov
from numpy.linalg import eig

def pca_test():
  ## seperate data into x y variables
  X = national_processed["CONTROL"]
  print(X)

  #calculate the means of column
  means = np.mean(X.T)
  print(means)

  ## Center each column at 0 by subtracting its mean
  center_d = X - means
  print(center_d)

  ## Divide each column by it's standard deviation
  std = np.std(X)
  print(std)

  # complete standardization by dividing std_dev
  standardized_data = center_d / std
  print(standardized_data)

  ## Calculate Variance-Covariance matrix of Z, wjat?
  covariance_matrix = cov(standardized_data.T)
  print(covariance_matrix)

  ## Eigenvectors and Eigenvalues of the Variance-Covarience Matrix
  values, vectors = eig(covariance_matrix)
  print(values)
  print(vectors)
  ## new data
  P = vectors.T.dot(standardized_data.T)


pca_test()
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 64530    64530
# 64531    64531
# 64532    64532
# 64533    64533
# 64534    64534
# Name: CONTROL, Length: 64535, dtype: int32
# 32267.0
# 0       -32267.0
# 1       -32266.0
# 2       -32265.0
# 3       -32264.0
# 4       -32263.0
#           ...
# 64530    32263.0
# 64531    32264.0
# 64532    32265.0
# 64533    32266.0
# 64534    32267.0
# Name: CONTROL, Length: 64535, dtype: float64
# 18629.649808839673
# 0       -1.732024
# 1       -1.731970
# 2       -1.731917
# 3       -1.731863
# 4       -1.731809
#            ...
# 64530    1.731809
# 64531    1.731863
# 64532    1.731917
# 64533    1.731970
# 64534    1.732024
# Name: CONTROL, Length: 64535, dtype: float64
# 1.0000154957076888
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ...

# %% [markdown]
# ### Scatterplot

# %% [markdown]
# # Stretch Goals
#
# ## 1) Perform further data exploration on the HADS national dataset (the version before we one-hot encoded it) Make scatterplots and see if you can see any resemblance between the original scatterplots and the plot of the principal components that you made in 7.1.
#
# (You may or may not not see very much resemblance depending on the variables you choose, and that's ok!)
#
# ## 2) Study "Scree Plots" and then try and make one for your PCA dataset. How many principal conponents do you need to retain in order for your PCs to contain 90% of the explained variance?
#
# We will present this topic formally at the beginning of tomorrow's lecture, so if you figure this stretch goal out, you're ahead of the game.
#
# ## 3) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# Prioritize self-study over this stretch goal if you are not semi-comfortable with the topics of PCA, Eigenvalues, and Eigenvectors.
#
# ![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)

# %% [markdown]
# ## Unzip

# %%
# !wget http://conradsanderson.id.au/lfwcrop/lfwcrop_grey.zip
# Out:
# --2020-05-21 19:49:35--  http://conradsanderson.id.au/lfwcrop/lfwcrop_grey.zip
# Resolving conradsanderson.id.au (conradsanderson.id.au)... 103.18.109.184, 2407:e700:2:13::e0
# Connecting to conradsanderson.id.au (conradsanderson.id.au)|103.18.109.184|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51132813 (49M) [application/zip]
# Saving to: ‘lfwcrop_grey.zip’
#
# lfwcrop_grey.zip    100%[===================>]  48.76M  12.0MB/s    in 5.2s
#
# 2020-05-21 19:49:41 (9.43 MB/s) - ‘lfwcrop_grey.zip’ saved [51132813/51132813]

# %%
# !unzip lfwcrop_grey.zip -d grey
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: grey/lfwcrop_grey/faces/Tony_Blair_0113.pgm
#   inflating: grey/lfwcrop_grey/faces/Paul_Coppin_0001.pgm
#   inflating: grey/lfwcrop_grey/faces/Herta_Daeubler-Gmelin_0002.pgm
#   inflating: grey/lfwcrop_grey/faces/Richard_Myers_0009.pgm
#   inflating: grey/lfwcrop_grey/faces/Kaye_Young_0001.pgm
#   inflating: grey/lfwcrop_grey/faces/Juan_Ignacio_Chela_0002.pgm
#   inflating: grey/lfwcrop_grey/faces/Paul_Wollnough_0001.pgm
#   inflating: grey/lfwcrop_grey/faces/Carolina_Moraes_0002.pgm
#   inflating: grey/lfwcrop_grey/faces/Charles_Taylor_0007.pgm
#   inflating: grey/lfwcrop_grey/faces/George_W_Bush_0006.pgm
#   inflating: grey/lfwcrop_grey/faces/Ian_Gillan_0001.pgm
#   inflating: grey/lfwcrop_grey/faces/Shaun_Pollock_0001.pgm
#   inflating: grey/lfwcrop_grey/faces/Junichiro_Koizumi_0022.pgm
#   inflating: grey/lfwcrop_grey/faces/Steve_Mariucci_0002.pgm
#   inflating: grey/lfwcrop_grey/faces/George_W_Bush_0214.pgm
# ...

# %% [markdown]
# ## PCA testing

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
# https://towardsdatascience.com/eigenfaces-recovering-humans-from-ghosts-17606c328184

# %%
"""It helps visualising the portraits from the dataset."""
def plot_portraits(images, titles, h, w, n_row, n_col):
    plt.figure(figsize=(2.2 * n_col, 2.2 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.20)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i])
        plt.xticks(())
        plt.yticks(())

# %%
dir='/content/grey/lfwcrop_grey/faces'
celebrity_photos=os.listdir(dir)[1:1001]
celebrity_images=[dir+'/' + photo for photo in celebrity_photos]
images=np.array([plt.imread(image) for image in celebrity_images], dtype=np.float64)
celebrity_names=[name[:name.find('0')-1].replace("_", " ") for name in celebrity_photos]
n_samples, h, w = images.shape
plot_portraits(images, celebrity_names, h, w, n_row=4, n_col=4)

# %%
def pca(X, n_pc):
  n_samples, n_features = X.shape
  mean                  = np.mean(X,axis=0)
  centered_data         = X-mean
  U, S, V               = np.linalg.svd(centered_data)
  components            = V[:n_pc]
  projected             = U[:, :n_pc]*S[:n_pc]
  return projected, components, mean, centered_data

# %% [markdown]
# ## HAHAHA I've seen these in my nightmares

# %%
n_components = 50
X = images.reshape(n_samples, h*w)
P, C, M, Y= pca(X, n_pc=n_components)
eigenfaces = C.reshape((n_components, h, w))
eigenface_titles = ["eigenface %d" % i for i in range(eigenfaces.shape[0])]
plot_portraits(eigenfaces, eigenface_titles, h, w, 4, 4)

# %%
def reconstruction(Y, C, M, h, w, image_index):
    n_samples, n_features = Y.shape
    weights = np.dot(Y, C.T)
    centered_vector=np.dot(weights[image_index, :], C)
    recovered_image=(M+centered_vector).reshape(h, w)
    return recovered_image
recovered_images=[reconstruction(Y, C, M, h, w, i) for i in range(len(images))]
plot_portraits(recovered_images, celebrity_names, h, w, n_row=4, n_col=4)
